# %%
# %run modelTrainTest.ipynb
# Out:
# ['switchfoot http twitpic com zl awww bummer shoulda got david carr third day'
#  'upset updat facebook text might cri result school today also blah'
#  'kenichan dive mani time ball manag save rest go bound' ...
#  'morn world take parent meal today ahem forgot rubi anniversari last week blame lisa'
#  'drive in fun say' 'like twitter page background']
# [0 0 0 ... 1 1 1]
# Shape of X (original feature dataset): (160000,)
# Shape of X_train (training feature dataset): (128000,)
# Shape of X_test (testing feature dataset): (32000,)
# ['aceconcierg enjoy weekend suzi'
#  'naasipop go gym car start stupid flat batteri nobodi push jump start'
#  'wish could hang stop act weird around hug someth best friend trust' ...
#  'tommcfli wish could hear mcfli radio bust work today though'
#  'ummeesa nope im crave havent forev'
#  'anoth minut bu depot termin frankfurt bu leav pm f']
# ['petewentz sound work'
#  'lclaurenconrad miss tonight episod wait come onlin'
# ...

# %% [markdown]
# ## Using the save model for future predictu=ion

# %%
import pickle

# %%
loaded_model = pickle.load(open('trained_model.suv', 'rb'))

# %%
x_new = X_test[200]
print(Y_test[200])

prediction = loaded_model.predict(x_new)
print(prediction)

if (prediction[0] == 0):
    print('Negative Tweet')
else:
    print('Positive Tweet')
# Out:
# 1
# [1]
# Positive Tweet

# %%
x_new = X_test[2]
print(Y_test[2]) #====> 0

prediction = loaded_model.predict(x_new)
print(prediction)  #====> [0]

if (prediction[0] == 0):      #===> Negative Tweet
    print('Negative Tweet')
else:
    print('Positive Tweet')
# Out:
# 0
# [0]
# Negative Tweet

# %%
total_tweets = x_new.shape

# %%
# Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# make predictions on the testing data
Y_pred = RFCmodel.predict(X_test)

# Create confusion matrx
cm = confusion_matrix(Y_test, Y_pred)

# %%
# print(Y_pred[0:100])

# %%
# print(cm)

# %%
# plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g',
            xticklabels=['Predict Negative', 'Predict Positive'],
            yticklabels=['Actual Negative', 'Actual Positive'])
plt.xlabel('Predicted labels')
plt.ylabel('Actual labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# Plot confusion matrix with count labels
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g',
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative', 'Actual Positive'])

# Add total count label
# plt.text(x,y,)
plt.text(1, -0.2, f'Total Tweets: {total_tweets}', ha='center', va='center', color='red', fontsize=14)
plt.text(1, 2.6, f'TruePositive: {cm[0][0]}\nFalseNegative: {cm[0][1]}\nFalsePositive: {cm[1][0]}\nTrueNegative: {cm[1][1]}\n', ha='center', va='bottom', color='green', fontsize=14)

plt.xlabel('Predicted labels')
plt.ylabel('Actual labels')
plt.title('Confusion Matrix ',fontsize=14)
plt.show()
